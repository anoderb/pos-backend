# %%
# Cell 1 — Install & Import Library
# !pip install -q tensorflowjs scikit-learn seaborn huggingface_hub

import os, sys, json, time, shutil, random, subprocess, warnings
from pathlib import Path
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, classification_report, confusion_matrix
)

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from huggingface_hub import snapshot_download

warnings.filterwarnings("ignore")
sns.set_theme(style="whitegrid")

def set_global_seed(seed):
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))

# %%
# Cell 2 — Konfigurasi (path, hyperparameter, daftar eksperimen)

SEED = 42

# ── HuggingFace Dataset (source of truth) ──────────────────────
HF_REPO_ID   = "Anoderb/dataset-collect"
HF_REPO_TYPE = "dataset"
# HF_TOKEN di-set dari Kaggle Secrets (Add-ons → Secrets → HF_TOKEN)
HF_TOKEN     = os.environ.get("HF_TOKEN", "")

# Download dataset dari HF — exclude thumbnails/ subdirectory
DATASET_DIR = Path("/kaggle/working/hf_dataset")
OUTPUT_ROOT = Path("/kaggle/working/Research_POS")

# Colab — uncomment jika pakai Colab:
# DATASET_DIR = Path("/content/DATASET")
# OUTPUT_ROOT = Path("/content/Research_POS")

IMAGE_SIZE    = (224, 224)
IMG_HEIGHT, IMG_WIDTH = IMAGE_SIZE
CHANNELS      = 3
NUM_CLASSES_EXPECTED = 24
BATCH_SIZE    = 32
MAX_EPOCHS    = 50

LEARNING_RATE = 1e-4
WEIGHT_DECAY  = 1e-4
LABEL_SMOOTHING = 0.1

EARLY_STOPPING_PATIENCE = 7
REDUCE_LR_PATIENCE      = 3
REDUCE_LR_FACTOR        = 0.2
MIN_LR                  = 1e-7
FINE_TUNE_LAST_N        = 15

TRAIN_SIZE      = 0.70
VALIDATION_SIZE = 0.15
TEST_SIZE       = 0.15

USE_CACHE    = True
CACHE_IN_RAM = True
CACHE_DIR    = Path("/kaggle/working/research_pos_cache")
if not CACHE_IN_RAM:
    CACHE_DIR.mkdir(parents=True, exist_ok=True)

USE_CUTMIX  = False
CUTMIX_ALPHA = 1.0

# Minimum file size — safety net untuk exclude thumbnail sisa
MIN_FILE_SIZE_BYTES = 10 * 1024  # 10 KB

AUTOTUNE = tf.data.AUTOTUNE

# Hanya 2 eksperimen
EXPERIMENTS = {
    "E1_MobileNetV3": {
        "backbone":   "MobileNetV3Large",
        "attention":  None,
    },
    "E2_MobileNetV3_CBAM": {
        "backbone":   "MobileNetV3Large",
        "attention":  "CBAM",
    },
}

for d in ["DATA_REPORT", "LOG", "COMPARISON", "FINAL_MODEL", "EXPERIMENT"]:
    (OUTPUT_ROOT / d).mkdir(parents=True, exist_ok=True)

print("Output:", OUTPUT_ROOT)
print("Experiments:", list(EXPERIMENTS.keys()))

# %%
# Cell 2b — Download dataset dari HuggingFace (exclude thumbnails)
#
# Thumbnail pattern di HF: data/{class-slug}/thumbnails/*.jpg (4-6KB each)
# Foto asli:               data/{class-slug}/*.jpg           (60-160KB each)
#
# 3 lapis filter thumbnail:
#   1. ignore_patterns saat download  — thumbnails/ tidak ikut di-download
#   2. glob("*") bukan rglob("*")     — hanya root class folder, bukan subdirectory
#   3. size check > 10KB              — safety net jika ada thumbnail lolos

print(f"Downloading dataset from HuggingFace: {HF_REPO_ID}")
print(f"  ignore_patterns: ['**/thumbnails/**']")

DATASET_DIR = Path(snapshot_download(
    repo_id=HF_REPO_ID,
    repo_type=HF_REPO_TYPE,
    token=HF_TOKEN if HF_TOKEN else None,
    local_dir=str(DATASET_DIR),
    ignore_patterns=["**/thumbnails/**"],
))

# Struktur HF: data/{class-slug}/*.jpg → point DATASET_DIR ke folder "data"
hf_data_dir = DATASET_DIR / "data"
if hf_data_dir.exists() and hf_data_dir.is_dir():
    DATASET_DIR = hf_data_dir

print(f"Dataset downloaded to: {DATASET_DIR}")

# Verifikasi: list class folders
class_folders = sorted([d.name for d in DATASET_DIR.iterdir() if d.is_dir()])
print(f"Class folders found: {len(class_folders)}")
for cf in class_folders:
    print(f"  {cf}")

# %%
# Cell 3 — Utility functions (folder, JSON, ukuran file, parameter count)

def ensure_dir(path):
    Path(path).mkdir(parents=True, exist_ok=True)
    return Path(path)

def save_json(data, path):
    path = Path(path)
    ensure_dir(path.parent)
    with open(path, "w") as f:
        json.dump(data, f, indent=4, default=str)

def save_text(text, path):
    path = Path(path)
    ensure_dir(path.parent)
    path.write_text(str(text), encoding="utf-8")

def now_string():
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def file_size_mb(path):
    path = Path(path)
    if path.is_file():
        return path.stat().st_size / (1024**2)
    if path.is_dir():
        return sum(f.stat().st_size for f in path.rglob("*") if f.is_file()) / (1024**2)
    return 0.0

def count_parameters(model):
    trainable     = int(np.sum([np.prod(v.shape) for v in model.trainable_variables]))
    non_trainable = int(np.sum([np.prod(v.shape) for v in model.non_trainable_variables]))
    return {
        "parameters":             trainable + non_trainable,
        "trainable_parameters":   trainable,
        "non_trainable_parameters": non_trainable,
    }

def get_last_4d_layer(model):
    for layer in reversed(model.layers):
        try:
            if len(layer.output.shape) == 4:
                return layer
        except Exception:
            pass
    return None

# %%
# Cell 4 — Kumpulkan file gambar, buat label, simpan class mapping & class.json
#
# FILTER THUMBNAIL (lapis 2 & 3):
#   - glob("*") bukan rglob("*") → hanya root class folder, skip subdirectory (thumbnails/)
#   - size check > MIN_FILE_SIZE_BYTES (10KB) → safety net

VALID_EXTENSIONS = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}

def collect_image_files(dataset_dir, min_size_bytes=10 * 1024):
    dataset_dir = Path(dataset_dir)
    records = []
    skipped_thumbnails = 0
    skipped_small = 0
    for class_dir in sorted(dataset_dir.iterdir()):
        if not class_dir.is_dir():
            continue
        # glob("*") — ROOT ONLY, tidak rekursif → thumbnails/ subdirectory di-skip
        for img_path in class_dir.glob("*"):
            if not img_path.is_file():
                continue
            if img_path.suffix.lower() not in VALID_EXTENSIONS:
                continue
            # Safety net: skip file < 10KB (thumbnail sisa)
            file_size = img_path.stat().st_size
            if file_size < min_size_bytes:
                skipped_small += 1
                continue
            records.append({
                "filepath": str(img_path),
                "class_name": class_dir.name,
                "file_size_kb": round(file_size / 1024, 1),
            })
    df = pd.DataFrame(records)
    if df.empty:
        raise FileNotFoundError(f"Tidak ada gambar valid di {dataset_dir}")
    class_names    = sorted(df["class_name"].unique())
    class_to_index = {name: idx for idx, name in enumerate(class_names)}
    df["label"]    = df["class_name"].map(class_to_index)
    print(f"File dikumpulkan: {len(df)}")
    print(f"File di-skip (< {min_size_bytes // 1024}KB): {skipped_small}")
    return df, class_names, class_to_index

image_df, CLASS_NAMES, CLASS_TO_INDEX = collect_image_files(DATASET_DIR, MIN_FILE_SIZE_BYTES)
NUM_CLASSES = len(CLASS_NAMES)

# class_mapping.json — index ke nama kelas
save_json(
    {"class_names": CLASS_NAMES, "class_to_index": CLASS_TO_INDEX,
     "num_classes": NUM_CLASSES, "num_images": len(image_df)},
    OUTPUT_ROOT / "DATA_REPORT" / "class_mapping.json",
)

# class.json — format inference TFJS: {"0": "nama_kelas", ...}
class_json = {str(idx): name for name, idx in CLASS_TO_INDEX.items()}
save_json(class_json, OUTPUT_ROOT / "DATA_REPORT" / "class.json")

print(f"Kelas   : {NUM_CLASSES}")
print(f"Gambar  : {len(image_df)}")
if NUM_CLASSES != NUM_CLASSES_EXPECTED:
    print(f"PERINGATAN: ekspektasi {NUM_CLASSES_EXPECTED} kelas, aktual {NUM_CLASSES}")
print(CLASS_NAMES)

# %%
# Cell 5 — Stratified split 70/15/15

train_df, tmp_df = train_test_split(
    image_df, test_size=(VALIDATION_SIZE + TEST_SIZE),
    stratify=image_df["label"], random_state=SEED,
)
relative_test = TEST_SIZE / (VALIDATION_SIZE + TEST_SIZE)
validation_df, test_df = train_test_split(
    tmp_df, test_size=relative_test,
    stratify=tmp_df["label"], random_state=SEED,
)

train_df      = train_df.reset_index(drop=True)
validation_df = validation_df.reset_index(drop=True)
test_df       = test_df.reset_index(drop=True)

print(f"Train      : {len(train_df)}")
print(f"Validation : {len(validation_df)}")
print(f"Test       : {len(test_df)}")

pd.concat([
    train_df.assign(split="train"),
    validation_df.assign(split="validation"),
    test_df.assign(split="test"),
], ignore_index=True).to_csv(OUTPUT_ROOT / "DATA_REPORT" / "dataset_split.csv", index=False)
# Out:
# Train      : 3360
# Validation : 720
# Test       : 720

# %%
# Cell 6 — Decode, resize (center-crop), augmentasi, CutMix, cache, prefetch

def decode_and_resize(path, label):
    """Resize sisi terpendek ≥ target lalu center-crop — menghindari distorsi dan black bar."""
    image = tf.io.read_file(path)
    image = tf.image.decode_image(image, channels=3, expand_animations=False)
    image.set_shape([None, None, 3])

    shape  = tf.shape(image)
    h, w   = tf.cast(shape[0], tf.float32), tf.cast(shape[1], tf.float32)
    scale  = tf.maximum(IMG_HEIGHT / h, IMG_WIDTH / w)
    new_h  = tf.cast(tf.round(h * scale), tf.int32)
    new_w  = tf.cast(tf.round(w * scale), tf.int32)

    image  = tf.image.resize(image, [new_h, new_w],
                             method=tf.image.ResizeMethod.BILINEAR, antialias=True)
    image  = tf.image.resize_with_crop_or_pad(image, IMG_HEIGHT, IMG_WIDTH)
    image  = tf.cast(image, tf.float32)
    label  = tf.one_hot(label, depth=NUM_CLASSES)
    return image, label

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08, fill_mode="reflect"),
    layers.RandomZoom((-0.10, 0.10), (-0.10, 0.10), fill_mode="reflect"),
    layers.RandomContrast(0.10),
    layers.RandomBrightness(0.10, value_range=(0.0, 255.0)),
], name="data_augmentation")

def cutmix_batch(images, labels, alpha=1.0):
    batch_size      = tf.shape(images)[0]
    idx             = tf.random.shuffle(tf.range(batch_size))
    shuf_images     = tf.gather(images, idx)
    shuf_labels     = tf.gather(labels, idx)
    lam             = tf.cast(tf.compat.v1.distributions.Beta(alpha, alpha).sample(), tf.float32)
    cut_ratio       = tf.sqrt(1.0 - lam)
    cut_h = tf.cast(tf.cast(IMG_HEIGHT, tf.float32) * cut_ratio, tf.int32)
    cut_w = tf.cast(tf.cast(IMG_WIDTH,  tf.float32) * cut_ratio, tf.int32)
    cy = tf.random.uniform([], 0, IMG_HEIGHT, dtype=tf.int32)
    cx = tf.random.uniform([], 0, IMG_WIDTH,  dtype=tf.int32)
    y1 = tf.clip_by_value(cy - cut_h // 2, 0, IMG_HEIGHT)
    y2 = tf.clip_by_value(cy + cut_h // 2, 0, IMG_HEIGHT)
    x1 = tf.clip_by_value(cx - cut_w // 2, 0, IMG_WIDTH)
    x2 = tf.clip_by_value(cx + cut_w // 2, 0, IMG_WIDTH)
    mask = tf.pad(tf.ones((y2 - y1, x2 - x1)),
                  [[y1, IMG_HEIGHT - y2], [x1, IMG_WIDTH - x2]])
    mask = tf.reshape(mask, [IMG_HEIGHT, IMG_WIDTH, 1])
    mixed_images = images * (1 - mask) + shuf_images * mask
    lam_adj = 1.0 - tf.cast((y2 - y1) * (x2 - x1), tf.float32) / tf.cast(IMG_HEIGHT * IMG_WIDTH, tf.float32)
    mixed_labels = lam_adj * labels + (1 - lam_adj) * shuf_labels
    return mixed_images, mixed_labels

def create_dataset(df, split_name, training=False):
    ds = tf.data.Dataset.from_tensor_slices(
        (df["filepath"].astype(str).values, df["label"].astype(np.int32).values)
    )
    ds = ds.map(decode_and_resize, num_parallel_calls=AUTOTUNE)
    if USE_CACHE:
        ds = ds.cache() if CACHE_IN_RAM else ds.cache(str(CACHE_DIR / f"{split_name}.cache"))
    if training:
        ds = ds.shuffle(len(df), seed=SEED, reshuffle_each_iteration=True)
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y),
                    num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH_SIZE, drop_remainder=False)
    if training and USE_CUTMIX:
        ds = ds.map(lambda x, y: cutmix_batch(x, y, CUTMIX_ALPHA), num_parallel_calls=AUTOTUNE)
    return ds.prefetch(AUTOTUNE)

train_ds      = create_dataset(train_df,      "train",      training=True)
validation_ds = create_dataset(validation_df, "validation", training=False)
test_ds       = create_dataset(test_df,       "test",       training=False)

print("Dataset siap. CutMix:", USE_CUTMIX, "| Cache:", USE_CACHE)
# Out:
# I0000 00:00:1785453473.992619      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1785453473.999260      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Dataset siap. CutMix: False | Cache: True

# %%
# Cell 7 — Implementasi CBAMLayer (satu-satunya attention yang dipakai)

class CBAMLayer(layers.Layer):
    """Convolutional Block Attention Module — channel + spatial attention."""

    def __init__(self, reduction_ratio=8, **kwargs):
        super().__init__(**kwargs)
        self.reduction_ratio = reduction_ratio

    def build(self, input_shape):
        channels = int(input_shape[-1])
        hidden   = max(channels // self.reduction_ratio, 1)
        self.ch_dense1   = layers.Dense(hidden,   activation="relu", use_bias=True)
        self.ch_dense2   = layers.Dense(channels, activation=None,   use_bias=True)
        self.spatial_conv = layers.Conv2D(1, kernel_size=7, padding="same",
                                          activation="sigmoid", use_bias=False)
        super().build(input_shape)

    def call(self, inputs):
        avg_p = tf.reduce_mean(inputs, axis=[1, 2])
        max_p = tf.reduce_max(inputs,  axis=[1, 2])
        ch_att = tf.nn.sigmoid(
            self.ch_dense2(self.ch_dense1(avg_p)) +
            self.ch_dense2(self.ch_dense1(max_p))
        )
        ch_att = tf.reshape(ch_att, [-1, 1, 1, tf.shape(ch_att)[-1]])
        x = inputs * ch_att
        sp_feat = tf.concat([
            tf.reduce_mean(x, axis=-1, keepdims=True),
            tf.reduce_max(x,  axis=-1, keepdims=True),
        ], axis=-1)
        return x * self.spatial_conv(sp_feat)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"reduction_ratio": self.reduction_ratio})
        return cfg

# %%
# Cell 8 — Build MobileNetV3Large ± CBAM, partial fine-tune, compile AdamW

def build_backbone(backbone_name, input_tensor):
    if backbone_name == "MobileNetV3Large":
        return tf.keras.applications.MobileNetV3Large(
            input_tensor=input_tensor,
            include_top=False,
            weights="imagenet",
            include_preprocessing=True,   # PENTING: preprocessing built-in
        )
    raise ValueError(f"Backbone tidak dikenal: {backbone_name}")

def set_partial_trainable(backbone, last_n=15):
    total = len(backbone.layers)
    for i, layer in enumerate(backbone.layers):
        if isinstance(layer, layers.BatchNormalization):
            layer.trainable = False
        else:
            layer.trainable = (i >= total - last_n)

def build_model(backbone_name, attention_name=None):
    inputs  = keras.Input(shape=(IMG_HEIGHT, IMG_WIDTH, CHANNELS), dtype=tf.float32)
    backbone = build_backbone(backbone_name, inputs)
    set_partial_trainable(backbone, last_n=FINE_TUNE_LAST_N)
    x = backbone.output
    if attention_name == "CBAM":
        x = CBAMLayer(reduction_ratio=8, name="cbam_attention")(x)
    x = layers.GlobalAveragePooling2D(name="gap")(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax", dtype="float32", name="predictions")(x)
    return keras.Model(inputs=inputs, outputs=outputs,
                       name=f"{backbone_name}_{attention_name or 'Baseline'}")

def compile_model(model):
    model.compile(
        optimizer=keras.optimizers.AdamW(learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY),
        loss=keras.losses.CategoricalCrossentropy(label_smoothing=LABEL_SMOOTHING),
        metrics=["accuracy", keras.metrics.TopKCategoricalAccuracy(k=5, name="top5_accuracy")],
    )
    return model

# %%
# Cell 9 — EarlyStopping, ReduceLR, ModelCheckpoint, dan fungsi train_experiment

class ResearchLogger(keras.callbacks.Callback):
    def __init__(self, log_path):
        super().__init__()
        self.log_path   = Path(log_path)
        self.start_time = None

    def _write(self, msg):
        with open(self.log_path, "a") as f:
            f.write(f"[{now_string()}] {msg}\n")

    def on_train_begin(self, logs=None):
        self.start_time = time.perf_counter()
        self._write("Start Training")

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        self._write(f"Epoch {epoch+1} | loss={logs.get('loss'):.4f} | "
                    f"acc={logs.get('accuracy'):.4f} | val_loss={logs.get('val_loss'):.4f} | "
                    f"val_acc={logs.get('val_accuracy'):.4f}")

    def on_train_end(self, logs=None):
        self._write(f"Done — {time.perf_counter() - self.start_time:.1f}s")

def create_experiment_dirs(name):
    exp_dir = OUTPUT_ROOT / "EXPERIMENT" / name
    for sub in ["checkpoint", "history", "model", "saved_model",
                "tensorflowjs", "tflite", "plots", "confusion_matrix",
                "prediction", "report", "weights", "log"]:
        ensure_dir(exp_dir / sub)
    return exp_dir

def create_callbacks(exp_dir):
    return [
        keras.callbacks.ModelCheckpoint(
            str(exp_dir / "checkpoint" / "best.weights.h5"),
            monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1),
        keras.callbacks.EarlyStopping(
            monitor="val_loss", patience=EARLY_STOPPING_PATIENCE,
            restore_best_weights=True, verbose=1),
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss", factor=REDUCE_LR_FACTOR,
            patience=REDUCE_LR_PATIENCE, min_lr=MIN_LR, verbose=1),
        ResearchLogger(exp_dir / "log" / "training.txt"),
    ]

def train_experiment(exp_name, exp_config):
    exp_dir = create_experiment_dirs(exp_name)
    model   = compile_model(build_model(exp_config["backbone"], exp_config["attention"]))

    print(f"\n{'='*70}\n{exp_name}\n{'='*70}")
    param_info = count_parameters(model)
    display(pd.DataFrame(param_info.items(), columns=["metric", "value"]))

    t0 = time.perf_counter()
    history = model.fit(
        train_ds, validation_data=validation_ds,
        epochs=MAX_EPOCHS, callbacks=create_callbacks(exp_dir), verbose=1,
    )
    train_time = time.perf_counter() - t0

    hist_df   = pd.DataFrame(history.history)
    best_epoch = int(hist_df["val_loss"].idxmin() + 1)
    hist_df.to_csv(exp_dir / "history" / "history.csv", index=False)

    # Plot training curve
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    axes[0].plot(hist_df["accuracy"],     label="Train");  axes[0].plot(hist_df["val_accuracy"], label="Val")
    axes[0].set_title(f"{exp_name} — Accuracy"); axes[0].legend()
    axes[1].plot(hist_df["loss"],         label="Train");  axes[1].plot(hist_df["val_loss"],     label="Val")
    axes[1].set_title(f"{exp_name} — Loss");     axes[1].legend()
    plt.tight_layout()
    plt.savefig(exp_dir / "plots" / "training_history.png", dpi=200)
    plt.show()

    model.save(exp_dir / "model" / "model.keras")
    model.save_weights(exp_dir / "weights" / "final.weights.h5")

    training_info = {
        **param_info,
        "training_time_seconds": train_time,
        "best_epoch": best_epoch,
        "best_val_accuracy": float(hist_df.loc[best_epoch - 1, "val_accuracy"]),
        "best_val_loss":     float(hist_df.loc[best_epoch - 1, "val_loss"]),
    }
    save_json(training_info, exp_dir / "report" / "training_info.json")

    return {"model": model, "history": hist_df,
            "experiment_dir": exp_dir, "training_info": training_info}

# %%
# Cell 10 — Training E1_MobileNetV3 dan E2_MobileNetV3_CBAM

RESULTS = {}

for exp_name, exp_config in EXPERIMENTS.items():
    set_global_seed(SEED)
    RESULTS[exp_name] = train_experiment(exp_name, exp_config)

print("\nSeluruh eksperimen selesai.")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# ======================================================================
# E1_MobileNetV3
# ======================================================================
#                      metric    value
# 0                parameters  3019418
# 1      trainable_parameters   816264
# 2  non_trainable_parameters  2203154
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785453507.912036      82 service.cc:152] XLA service 0x79885c113270 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1785453507.912079      82 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1785453507.912084      82 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1785453510.039115      82 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-07-30 23:18:40.726959: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-30 23:18:40.865683: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-30 23:18:41.214484: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-30 23:18:41.352880: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1785453526.556609      82 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.0714 - loss: 3.5739 - top5_accuracy: 0.2842
# 2026-07-30 23:19:24.177385: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-30 23:19:24.311769: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-30 23:19:24.631029: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-30 23:19:24.768869: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from None to 2.45849, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 1: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 90s 404ms/step - accuracy: 0.1170 - loss: 3.1950 - top5_accuracy: 0.3926 - val_accuracy: 0.4236 - val_loss: 2.4585 - val_top5_accuracy: 0.8000 - learning_rate: 1.0000e-04
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.3675 - loss: 2.3904 - top5_accuracy: 0.7242
# Epoch 2: val_loss improved from 2.45849 to 1.34021, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 2: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.4470 - loss: 2.1511 - top5_accuracy: 0.7991 - val_accuracy: 0.8264 - val_loss: 1.3402 - val_top5_accuracy: 0.9750 - learning_rate: 1.0000e-04
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6730 - loss: 1.5579 - top5_accuracy: 0.9519
# Epoch 3: val_loss improved from 1.34021 to 1.03575, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 3: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.7104 - loss: 1.4699 - top5_accuracy: 0.9583 - val_accuracy: 0.9028 - val_loss: 1.0357 - val_top5_accuracy: 0.9931 - learning_rate: 1.0000e-04
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8026 - loss: 1.2363 - top5_accuracy: 0.9808
# Epoch 4: val_loss improved from 1.03575 to 0.94473, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 4: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.8238 - loss: 1.1895 - top5_accuracy: 0.9851 - val_accuracy: 0.9375 - val_loss: 0.9447 - val_top5_accuracy: 0.9944 - learning_rate: 1.0000e-04
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8775 - loss: 1.0849 - top5_accuracy: 0.9925
# Epoch 5: val_loss improved from 0.94473 to 0.89335, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 5: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.8810 - loss: 1.0691 - top5_accuracy: 0.9926 - val_accuracy: 0.9597 - val_loss: 0.8934 - val_top5_accuracy: 0.9972 - learning_rate: 1.0000e-04
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9013 - loss: 1.0072 - top5_accuracy: 0.9939
# Epoch 6: val_loss improved from 0.89335 to 0.86080, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 6: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9051 - loss: 0.9943 - top5_accuracy: 0.9964 - val_accuracy: 0.9611 - val_loss: 0.8608 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9340 - loss: 0.9516 - top5_accuracy: 0.9956
# Epoch 7: val_loss improved from 0.86080 to 0.83456, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 7: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9384 - loss: 0.9397 - top5_accuracy: 0.9973 - val_accuracy: 0.9736 - val_loss: 0.8346 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9501 - loss: 0.9171 - top5_accuracy: 0.9959
# Epoch 8: val_loss improved from 0.83456 to 0.81042, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 8: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9518 - loss: 0.9079 - top5_accuracy: 0.9982 - val_accuracy: 0.9792 - val_loss: 0.8104 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9603 - loss: 0.8679 - top5_accuracy: 0.9999
# Epoch 9: val_loss improved from 0.81042 to 0.79711, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 9: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9613 - loss: 0.8707 - top5_accuracy: 0.9994 - val_accuracy: 0.9806 - val_loss: 0.7971 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9687 - loss: 0.8548 - top5_accuracy: 0.9999
# Epoch 10: val_loss improved from 0.79711 to 0.78778, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 10: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9693 - loss: 0.8526 - top5_accuracy: 0.9994 - val_accuracy: 0.9806 - val_loss: 0.7878 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 11/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9712 - loss: 0.8343 - top5_accuracy: 0.9998
# Epoch 11: val_loss improved from 0.78778 to 0.77620, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 11: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - accuracy: 0.9688 - loss: 0.8368 - top5_accuracy: 0.9994 - val_accuracy: 0.9847 - val_loss: 0.7762 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9708 - loss: 0.8226 - top5_accuracy: 1.0000
# Epoch 12: val_loss improved from 0.77620 to 0.76844, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 12: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9762 - loss: 0.8137 - top5_accuracy: 1.0000 - val_accuracy: 0.9806 - val_loss: 0.7684 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9808 - loss: 0.8128 - top5_accuracy: 1.0000
# Epoch 13: val_loss improved from 0.76844 to 0.76127, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 13: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9762 - loss: 0.8095 - top5_accuracy: 1.0000 - val_accuracy: 0.9861 - val_loss: 0.7613 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9881 - loss: 0.7857 - top5_accuracy: 1.0000
# Epoch 14: val_loss improved from 0.76127 to 0.75322, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 14: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9869 - loss: 0.7895 - top5_accuracy: 1.0000 - val_accuracy: 0.9889 - val_loss: 0.7532 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9900 - loss: 0.7839 - top5_accuracy: 1.0000
# Epoch 15: val_loss improved from 0.75322 to 0.75122, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 15: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9875 - loss: 0.7830 - top5_accuracy: 1.0000 - val_accuracy: 0.9861 - val_loss: 0.7512 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9887 - loss: 0.7702 - top5_accuracy: 1.0000
# Epoch 16: val_loss improved from 0.75122 to 0.74549, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 16: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9878 - loss: 0.7741 - top5_accuracy: 1.0000 - val_accuracy: 0.9875 - val_loss: 0.7455 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9875 - loss: 0.7721 - top5_accuracy: 1.0000
# Epoch 17: val_loss improved from 0.74549 to 0.73976, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 17: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9899 - loss: 0.7687 - top5_accuracy: 1.0000 - val_accuracy: 0.9875 - val_loss: 0.7398 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9906 - loss: 0.7610 - top5_accuracy: 1.0000
# Epoch 18: val_loss improved from 0.73976 to 0.73795, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 18: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9923 - loss: 0.7585 - top5_accuracy: 1.0000 - val_accuracy: 0.9847 - val_loss: 0.7380 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9933 - loss: 0.7525 - top5_accuracy: 1.0000
# Epoch 19: val_loss improved from 0.73795 to 0.72996, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 19: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9923 - loss: 0.7550 - top5_accuracy: 1.0000 - val_accuracy: 0.9889 - val_loss: 0.7300 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9905 - loss: 0.7490 - top5_accuracy: 1.0000
# Epoch 20: val_loss improved from 0.72996 to 0.72862, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 20: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9908 - loss: 0.7499 - top5_accuracy: 1.0000 - val_accuracy: 0.9917 - val_loss: 0.7286 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 21/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9965 - loss: 0.7378 - top5_accuracy: 1.0000
# Epoch 21: val_loss improved from 0.72862 to 0.72681, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 21: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9958 - loss: 0.7414 - top5_accuracy: 1.0000 - val_accuracy: 0.9903 - val_loss: 0.7268 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 22/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9967 - loss: 0.7337 - top5_accuracy: 1.0000
# Epoch 22: val_loss improved from 0.72681 to 0.72549, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 22: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9961 - loss: 0.7339 - top5_accuracy: 1.0000 - val_accuracy: 0.9917 - val_loss: 0.7255 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 23/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9982 - loss: 0.7287 - top5_accuracy: 1.0000
# Epoch 23: val_loss improved from 0.72549 to 0.72144, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 23: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9973 - loss: 0.7305 - top5_accuracy: 1.0000 - val_accuracy: 0.9903 - val_loss: 0.7214 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 24/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9978 - loss: 0.7274 - top5_accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.72144
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 187ms/step - accuracy: 0.9979 - loss: 0.7266 - top5_accuracy: 1.0000 - val_accuracy: 0.9903 - val_loss: 0.7217 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 25/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9972 - loss: 0.7222 - top5_accuracy: 1.0000
# Epoch 25: val_loss improved from 0.72144 to 0.72009, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 25: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9970 - loss: 0.7228 - top5_accuracy: 1.0000 - val_accuracy: 0.9875 - val_loss: 0.7201 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 26/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9976 - loss: 0.7176 - top5_accuracy: 1.0000
# Epoch 26: val_loss improved from 0.72009 to 0.71839, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 26: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9985 - loss: 0.7179 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.7184 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 27/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9988 - loss: 0.7193 - top5_accuracy: 1.0000
# Epoch 27: val_loss improved from 0.71839 to 0.71215, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 27: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9985 - loss: 0.7171 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.7121 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 28/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9952 - loss: 0.7155 - top5_accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.71215
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 187ms/step - accuracy: 0.9967 - loss: 0.7129 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.7145 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 29/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9983 - loss: 0.7115 - top5_accuracy: 1.0000
# Epoch 29: val_loss improved from 0.71215 to 0.71050, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 29: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9994 - loss: 0.7101 - top5_accuracy: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.7105 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 30/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9981 - loss: 0.7104 - top5_accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.71050
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9988 - loss: 0.7089 - top5_accuracy: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.7113 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 31/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9997 - loss: 0.7053 - top5_accuracy: 1.0000
# Epoch 31: val_loss improved from 0.71050 to 0.70800, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 31: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9994 - loss: 0.7053 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.7080 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 32/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9989 - loss: 0.7003 - top5_accuracy: 1.0000
# Epoch 32: val_loss improved from 0.70800 to 0.70762, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 32: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9985 - loss: 0.7033 - top5_accuracy: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.7076 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 33/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9988 - loss: 0.6975 - top5_accuracy: 1.0000
# Epoch 33: val_loss improved from 0.70762 to 0.70628, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 33: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 0.9988 - loss: 0.6994 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.7063 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 34/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9980 - loss: 0.7035 - top5_accuracy: 1.0000
# Epoch 34: val_loss improved from 0.70628 to 0.70616, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 34: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - accuracy: 0.9985 - loss: 0.7027 - top5_accuracy: 1.0000 - val_accuracy: 0.9931 - val_loss: 0.7062 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 35/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9999 - loss: 0.6972 - top5_accuracy: 1.0000
# Epoch 35: val_loss improved from 0.70616 to 0.70450, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 35: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 192ms/step - accuracy: 0.9997 - loss: 0.6981 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.7045 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 36/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9992 - loss: 0.6940 - top5_accuracy: 1.0000
# Epoch 36: val_loss improved from 0.70450 to 0.70203, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 36: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9991 - loss: 0.6963 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.7020 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 37/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9998 - loss: 0.6920 - top5_accuracy: 1.0000
# Epoch 37: val_loss did not improve from 0.70203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - accuracy: 0.9994 - loss: 0.6926 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.7031 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 38/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9998 - loss: 0.6935 - top5_accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.70203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 187ms/step - accuracy: 0.9997 - loss: 0.6915 - top5_accuracy: 1.0000 - val_accuracy: 0.9931 - val_loss: 0.7055 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 39/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9998 - loss: 0.6922 - top5_accuracy: 1.0000
# Epoch 39: val_loss improved from 0.70203 to 0.69989, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 39: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9997 - loss: 0.6898 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.6999 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 40/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9994 - loss: 0.6886 - top5_accuracy: 1.0000
# Epoch 40: val_loss improved from 0.69989 to 0.69877, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 40: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9994 - loss: 0.6884 - top5_accuracy: 1.0000 - val_accuracy: 0.9931 - val_loss: 0.6988 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 41/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9986 - loss: 0.6873 - top5_accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.69877
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - accuracy: 0.9994 - loss: 0.6882 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.7002 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 42/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9998 - loss: 0.6843 - top5_accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.69877
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 187ms/step - accuracy: 0.9994 - loss: 0.6862 - top5_accuracy: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.7006 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 43/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 1.0000 - loss: 0.6855 - top5_accuracy: 1.0000
# Epoch 43: val_loss improved from 0.69877 to 0.69637, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 43: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 1.0000 - loss: 0.6840 - top5_accuracy: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.6964 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 44/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9987 - loss: 0.6827 - top5_accuracy: 1.0000
# Epoch 44: val_loss improved from 0.69637 to 0.69581, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 44: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9997 - loss: 0.6808 - top5_accuracy: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.6958 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 45/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9997 - loss: 0.6830 - top5_accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.69581
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9997 - loss: 0.6836 - top5_accuracy: 1.0000 - val_accuracy: 0.9931 - val_loss: 0.6978 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 46/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9987 - loss: 0.6814 - top5_accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.69581
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9997 - loss: 0.6804 - top5_accuracy: 1.0000 - val_accuracy: 0.9931 - val_loss: 0.6975 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 47/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 1.0000 - loss: 0.6799 - top5_accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.69581
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 187ms/step - accuracy: 0.9997 - loss: 0.6800 - top5_accuracy: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.7001 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 48/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9995 - loss: 0.6787 - top5_accuracy: 1.0000
# Epoch 48: val_loss improved from 0.69581 to 0.69488, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 48: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9997 - loss: 0.6778 - top5_accuracy: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.6949 - val_top5_accuracy: 1.0000 - learning_rate: 2.0000e-05
# Epoch 49/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9989 - loss: 0.6812 - top5_accuracy: 1.0000
# Epoch 49: val_loss improved from 0.69488 to 0.69434, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 49: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9991 - loss: 0.6805 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.6943 - val_top5_accuracy: 1.0000 - learning_rate: 2.0000e-05
# Epoch 50/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9999 - loss: 0.6781 - top5_accuracy: 1.0000
# Epoch 50: val_loss improved from 0.69434 to 0.69413, saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
#
# Epoch 50: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - accuracy: 0.9997 - loss: 0.6771 - top5_accuracy: 1.0000 - val_accuracy: 0.9958 - val_loss: 0.6941 - val_top5_accuracy: 1.0000 - learning_rate: 2.0000e-05
# Restoring model weights from the end of the best epoch: 50.
# ======================================================================
# E2_MobileNetV3_CBAM
# ======================================================================
#                      metric    value
# 0                parameters  3250996
# 1      trainable_parameters  1047842
# 2  non_trainable_parameters  2203154
# Epoch 1/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.0649 - loss: 3.1694 - top5_accuracy: 0.2882
# Epoch 1: val_loss improved from None to 2.42605, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 1: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 50s 307ms/step - accuracy: 0.1199 - loss: 3.0257 - top5_accuracy: 0.4077 - val_accuracy: 0.4361 - val_loss: 2.4261 - val_top5_accuracy: 0.8417 - learning_rate: 1.0000e-04
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.4530 - loss: 2.1529 - top5_accuracy: 0.8153
# Epoch 2: val_loss improved from 2.42605 to 1.13555, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 2: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - accuracy: 0.5449 - loss: 1.8786 - top5_accuracy: 0.8759 - val_accuracy: 0.8514 - val_loss: 1.1355 - val_top5_accuracy: 0.9917 - learning_rate: 1.0000e-04
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.7502 - loss: 1.3459 - top5_accuracy: 0.9707
# Epoch 3: val_loss improved from 1.13555 to 0.94916, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 3: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.7801 - loss: 1.2863 - top5_accuracy: 0.9747 - val_accuracy: 0.9417 - val_loss: 0.9492 - val_top5_accuracy: 0.9958 - learning_rate: 1.0000e-04
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8644 - loss: 1.1149 - top5_accuracy: 0.9889
# Epoch 4: val_loss improved from 0.94916 to 0.88658, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 4: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.8711 - loss: 1.0911 - top5_accuracy: 0.9911 - val_accuracy: 0.9431 - val_loss: 0.8866 - val_top5_accuracy: 0.9972 - learning_rate: 1.0000e-04
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8901 - loss: 1.0273 - top5_accuracy: 0.9957
# Epoch 5: val_loss improved from 0.88658 to 0.84574, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 5: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - accuracy: 0.9042 - loss: 1.0041 - top5_accuracy: 0.9946 - val_accuracy: 0.9583 - val_loss: 0.8457 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9366 - loss: 0.9395 - top5_accuracy: 0.9974
# Epoch 6: val_loss improved from 0.84574 to 0.81636, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 6: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9375 - loss: 0.9325 - top5_accuracy: 0.9967 - val_accuracy: 0.9722 - val_loss: 0.8164 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9473 - loss: 0.9081 - top5_accuracy: 0.9948
# Epoch 7: val_loss improved from 0.81636 to 0.80347, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 7: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9524 - loss: 0.8961 - top5_accuracy: 0.9967 - val_accuracy: 0.9694 - val_loss: 0.8035 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9584 - loss: 0.8634 - top5_accuracy: 0.9994
# Epoch 8: val_loss improved from 0.80347 to 0.78423, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 8: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9640 - loss: 0.8611 - top5_accuracy: 0.9994 - val_accuracy: 0.9764 - val_loss: 0.7842 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9700 - loss: 0.8352 - top5_accuracy: 0.9989
# Epoch 9: val_loss improved from 0.78423 to 0.76935, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 9: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9699 - loss: 0.8344 - top5_accuracy: 0.9994 - val_accuracy: 0.9806 - val_loss: 0.7694 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9804 - loss: 0.8094 - top5_accuracy: 0.9992
# Epoch 10: val_loss improved from 0.76935 to 0.76037, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 10: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 198ms/step - accuracy: 0.9795 - loss: 0.8116 - top5_accuracy: 0.9991 - val_accuracy: 0.9861 - val_loss: 0.7604 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 11/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9766 - loss: 0.7993 - top5_accuracy: 0.9999
# Epoch 11: val_loss improved from 0.76037 to 0.75066, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 11: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9795 - loss: 0.7970 - top5_accuracy: 0.9997 - val_accuracy: 0.9847 - val_loss: 0.7507 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9870 - loss: 0.7844 - top5_accuracy: 0.9998
# Epoch 12: val_loss improved from 0.75066 to 0.74548, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 12: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.9854 - loss: 0.7870 - top5_accuracy: 0.9997 - val_accuracy: 0.9847 - val_loss: 0.7455 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9887 - loss: 0.7696 - top5_accuracy: 1.0000
# Epoch 13: val_loss improved from 0.74548 to 0.73689, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 13: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.9899 - loss: 0.7651 - top5_accuracy: 1.0000 - val_accuracy: 0.9875 - val_loss: 0.7369 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9902 - loss: 0.7640 - top5_accuracy: 1.0000
# Epoch 14: val_loss improved from 0.73689 to 0.73187, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 14: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9905 - loss: 0.7599 - top5_accuracy: 1.0000 - val_accuracy: 0.9875 - val_loss: 0.7319 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9956 - loss: 0.7497 - top5_accuracy: 0.9999
# Epoch 15: val_loss improved from 0.73187 to 0.72860, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 15: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.9929 - loss: 0.7507 - top5_accuracy: 0.9997 - val_accuracy: 0.9861 - val_loss: 0.7286 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9940 - loss: 0.7471 - top5_accuracy: 1.0000
# Epoch 16: val_loss improved from 0.72860 to 0.72825, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 16: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9940 - loss: 0.7456 - top5_accuracy: 1.0000 - val_accuracy: 0.9819 - val_loss: 0.7282 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9961 - loss: 0.7300 - top5_accuracy: 1.0000
# Epoch 17: val_loss improved from 0.72825 to 0.72121, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 17: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9961 - loss: 0.7322 - top5_accuracy: 1.0000 - val_accuracy: 0.9861 - val_loss: 0.7212 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9954 - loss: 0.7275 - top5_accuracy: 1.0000
# Epoch 18: val_loss improved from 0.72121 to 0.71628, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 18: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9949 - loss: 0.7280 - top5_accuracy: 1.0000 - val_accuracy: 0.9875 - val_loss: 0.7163 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9971 - loss: 0.7244 - top5_accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.71628
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - accuracy: 0.9961 - loss: 0.7249 - top5_accuracy: 1.0000 - val_accuracy: 0.9819 - val_loss: 0.7197 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9991 - loss: 0.7183 - top5_accuracy: 1.0000
# Epoch 20: val_loss improved from 0.71628 to 0.71587, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 20: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9988 - loss: 0.7198 - top5_accuracy: 1.0000 - val_accuracy: 0.9875 - val_loss: 0.7159 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 21/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9965 - loss: 0.7170 - top5_accuracy: 0.9993
# Epoch 21: val_loss improved from 0.71587 to 0.70907, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 21: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 198ms/step - accuracy: 0.9976 - loss: 0.7145 - top5_accuracy: 0.9997 - val_accuracy: 0.9833 - val_loss: 0.7091 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 22/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9985 - loss: 0.7101 - top5_accuracy: 1.0000
# Epoch 22: val_loss improved from 0.70907 to 0.70808, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 22: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9979 - loss: 0.7092 - top5_accuracy: 1.0000 - val_accuracy: 0.9889 - val_loss: 0.7081 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 23/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9985 - loss: 0.7086 - top5_accuracy: 1.0000
# Epoch 23: val_loss improved from 0.70808 to 0.70203, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 23: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9982 - loss: 0.7068 - top5_accuracy: 1.0000 - val_accuracy: 0.9917 - val_loss: 0.7020 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 24/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9996 - loss: 0.6995 - top5_accuracy: 1.0000
# Epoch 24: val_loss improved from 0.70203 to 0.70101, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 24: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.9988 - loss: 0.7006 - top5_accuracy: 1.0000 - val_accuracy: 0.9917 - val_loss: 0.7010 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 25/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9983 - loss: 0.7040 - top5_accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.70101
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - accuracy: 0.9973 - loss: 0.7050 - top5_accuracy: 1.0000 - val_accuracy: 0.9861 - val_loss: 0.7028 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 26/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9998 - loss: 0.6965 - top5_accuracy: 1.0000
# Epoch 26: val_loss improved from 0.70101 to 0.70056, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 26: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9991 - loss: 0.6980 - top5_accuracy: 1.0000 - val_accuracy: 0.9861 - val_loss: 0.7006 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 27/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9993 - loss: 0.6940 - top5_accuracy: 1.0000
# Epoch 27: val_loss improved from 0.70056 to 0.69559, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 27: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9991 - loss: 0.6923 - top5_accuracy: 1.0000 - val_accuracy: 0.9917 - val_loss: 0.6956 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 28/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9996 - loss: 0.6901 - top5_accuracy: 1.0000
# Epoch 28: val_loss improved from 0.69559 to 0.69533, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 28: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9994 - loss: 0.6910 - top5_accuracy: 1.0000 - val_accuracy: 0.9903 - val_loss: 0.6953 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 29/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.6889 - top5_accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.69533
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 1.0000 - loss: 0.6881 - top5_accuracy: 1.0000 - val_accuracy: 0.9931 - val_loss: 0.6964 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 30/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9995 - loss: 0.6883 - top5_accuracy: 1.0000
# Epoch 30: val_loss improved from 0.69533 to 0.69322, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 30: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9997 - loss: 0.6863 - top5_accuracy: 1.0000 - val_accuracy: 0.9889 - val_loss: 0.6932 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 31/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9999 - loss: 0.6868 - top5_accuracy: 1.0000
# Epoch 31: val_loss improved from 0.69322 to 0.69115, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 31: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.9997 - loss: 0.6852 - top5_accuracy: 1.0000 - val_accuracy: 0.9903 - val_loss: 0.6912 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 32/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9996 - loss: 0.6827 - top5_accuracy: 1.0000
# Epoch 32: val_loss did not improve from 0.69115
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - accuracy: 0.9988 - loss: 0.6841 - top5_accuracy: 1.0000 - val_accuracy: 0.9889 - val_loss: 0.6936 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 33/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9998 - loss: 0.6818 - top5_accuracy: 1.0000
# Epoch 33: val_loss improved from 0.69115 to 0.68765, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 33: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9997 - loss: 0.6814 - top5_accuracy: 1.0000 - val_accuracy: 0.9917 - val_loss: 0.6876 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 34/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 1.0000 - loss: 0.6788 - top5_accuracy: 1.0000
# Epoch 34: val_loss improved from 0.68765 to 0.68490, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 34: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 1.0000 - loss: 0.6786 - top5_accuracy: 1.0000 - val_accuracy: 0.9917 - val_loss: 0.6849 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 35/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.6776 - top5_accuracy: 1.0000
# Epoch 35: val_loss improved from 0.68490 to 0.68447, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 35: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.9997 - loss: 0.6777 - top5_accuracy: 1.0000 - val_accuracy: 0.9917 - val_loss: 0.6845 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 36/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9993 - loss: 0.6757 - top5_accuracy: 1.0000
# Epoch 36: val_loss did not improve from 0.68447
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - accuracy: 0.9991 - loss: 0.6775 - top5_accuracy: 1.0000 - val_accuracy: 0.9903 - val_loss: 0.6874 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 37/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9997 - loss: 0.6772 - top5_accuracy: 1.0000
# Epoch 37: val_loss did not improve from 0.68447
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 189ms/step - accuracy: 0.9997 - loss: 0.6755 - top5_accuracy: 1.0000 - val_accuracy: 0.9861 - val_loss: 0.6869 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 38/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9999 - loss: 0.6727 - top5_accuracy: 1.0000
# Epoch 38: val_loss improved from 0.68447 to 0.68296, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 38: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 201ms/step - accuracy: 0.9997 - loss: 0.6730 - top5_accuracy: 1.0000 - val_accuracy: 0.9903 - val_loss: 0.6830 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 39/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9996 - loss: 0.6728 - top5_accuracy: 1.0000
# Epoch 39: val_loss improved from 0.68296 to 0.68264, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 39: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.9997 - loss: 0.6724 - top5_accuracy: 1.0000 - val_accuracy: 0.9931 - val_loss: 0.6826 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 40/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9995 - loss: 0.6700 - top5_accuracy: 1.0000
# Epoch 40: val_loss improved from 0.68264 to 0.68121, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 40: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.9997 - loss: 0.6707 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.6812 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 41/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9999 - loss: 0.6707 - top5_accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.68121
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - accuracy: 0.9997 - loss: 0.6702 - top5_accuracy: 1.0000 - val_accuracy: 0.9917 - val_loss: 0.6825 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 42/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9995 - loss: 0.6687 - top5_accuracy: 1.0000
# Epoch 42: val_loss improved from 0.68121 to 0.67930, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 42: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.9994 - loss: 0.6687 - top5_accuracy: 1.0000 - val_accuracy: 0.9903 - val_loss: 0.6793 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 43/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 1.0000 - loss: 0.6675 - top5_accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.67930
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - accuracy: 1.0000 - loss: 0.6685 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.6802 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 44/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 1.0000 - loss: 0.6632 - top5_accuracy: 1.0000
# Epoch 44: val_loss improved from 0.67930 to 0.67516, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 44: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 1.0000 - loss: 0.6649 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.6752 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 45/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 1.0000 - loss: 0.6645 - top5_accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.67516
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 192ms/step - accuracy: 1.0000 - loss: 0.6637 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.6774 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 46/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.6624 - top5_accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.67516
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 189ms/step - accuracy: 1.0000 - loss: 0.6628 - top5_accuracy: 1.0000 - val_accuracy: 0.9944 - val_loss: 0.6783 - val_top5_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 47/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 1.0000 - loss: 0.6645 - top5_accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.67516
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - accuracy: 1.0000 - loss: 0.6655 - top5_accuracy: 1.0000 - val_accuracy: 0.9903 - val_loss: 0.6827 - val_top5_accuracy: 0.9986 - learning_rate: 1.0000e-04
# Epoch 48/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 1.0000 - loss: 0.6594 - top5_accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.67516
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 191ms/step - accuracy: 1.0000 - loss: 0.6593 - top5_accuracy: 1.0000 - val_accuracy: 0.9931 - val_loss: 0.6762 - val_top5_accuracy: 0.9986 - learning_rate: 2.0000e-05
# Epoch 49/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 1.0000 - loss: 0.6601 - top5_accuracy: 1.0000
# Epoch 49: val_loss improved from 0.67516 to 0.67467, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 49: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - accuracy: 1.0000 - loss: 0.6596 - top5_accuracy: 1.0000 - val_accuracy: 0.9931 - val_loss: 0.6747 - val_top5_accuracy: 0.9986 - learning_rate: 2.0000e-05
# Epoch 50/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 1.0000 - loss: 0.6593 - top5_accuracy: 1.0000
# Epoch 50: val_loss improved from 0.67467 to 0.67398, saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
#
# Epoch 50: finished saving model to /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/checkpoint/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 1.0000 - loss: 0.6588 - top5_accuracy: 1.0000 - val_accuracy: 0.9931 - val_loss: 0.6740 - val_top5_accuracy: 0.9986 - learning_rate: 2.0000e-05
# Restoring model weights from the end of the best epoch: 50.
# Seluruh eksperimen selesai.

# %%
# Cell 11 — Prediksi test set, hitung metrik, confusion matrix, classification report
#          + simpan kesalahan model (misclassified.csv + error_summary.csv)

def predict_dataset(model, dataset):
    y_true, y_prob = [], []
    for images, labels in dataset:
        y_prob.append(model.predict(images, verbose=0))
        y_true.append(labels.numpy() if hasattr(labels, "numpy") else np.asarray(labels))
    y_true = np.concatenate(y_true)
    y_prob = np.concatenate(y_prob)
    return np.argmax(y_true, 1), np.argmax(y_prob, 1), y_true, y_prob

def measure_inference(model, dataset, n_warmup=3):
    batch_images = next(iter(dataset))[0]
    for _ in range(n_warmup):
        model(batch_images, training=False)
    t0, total = time.perf_counter(), 0
    for images, _ in dataset:
        model(images, training=False); total += images.shape[0]
    elapsed = time.perf_counter() - t0
    return {"inference_time_per_image_ms": elapsed / total * 1000, "fps": total / elapsed}

def save_misclassified(y_true_ids, y_pred_ids, y_prob, test_df, exp_dir):
    """Simpan detail kesalahan model: true label, predicted label, confidence."""
    misclassified_idx = np.where(y_true_ids != y_pred_ids)[0]
    if len(misclassified_idx) == 0:
        print("  Tidak ada kesalahan klasifikasi!")
        empty_df = pd.DataFrame(columns=[
            "filepath", "true_label", "predicted_label", "confidence", "true_confidence"
        ])
        empty_df.to_csv(exp_dir / "report" / "misclassified.csv", index=False)
        empty_df.to_csv(exp_dir / "confusion_matrix" / "error_summary.csv", index=False)
        return empty_df

    rows = []
    for idx in misclassified_idx:
        true_label = CLASS_NAMES[y_true_ids[idx]]
        pred_label = CLASS_NAMES[y_pred_ids[idx]]
        confidence = float(y_prob[idx, y_pred_ids[idx]])
        true_conf  = float(y_prob[idx, y_true_ids[idx]])
        rows.append({
            "filepath":       test_df.iloc[idx]["filepath"],
            "true_label":     true_label,
            "predicted_label": pred_label,
            "confidence":     round(confidence, 4),
            "true_confidence": round(true_conf, 4),
        })
    mis_df = pd.DataFrame(rows)
    mis_df.to_csv(exp_dir / "report" / "misclassified.csv", index=False)

    # Error summary: per class — total error, most confused with
    error_rows = []
    for true_cls in CLASS_NAMES:
        cls_errors = mis_df[mis_df["true_label"] == true_cls]
        if len(cls_errors) == 0:
            continue
        most_confused = cls_errors["predicted_label"].value_counts().idxmax()
        most_confused_count = int(cls_errors["predicted_label"].value_counts().max())
        avg_confidence = float(cls_errors["confidence"].mean())
        error_rows.append({
            "true_label":         true_cls,
            "total_errors":       len(cls_errors),
            "most_confused_with": most_confused,
            "most_confused_count": most_confused_count,
            "avg_confidence":     round(avg_confidence, 4),
        })
    error_summary_df = pd.DataFrame(error_rows).sort_values("total_errors", ascending=False)
    error_summary_df.to_csv(exp_dir / "confusion_matrix" / "error_summary.csv", index=False)

    print(f"  Total misclassified: {len(mis_df)}")
    print(f"  Classes with errors: {len(error_summary_df)}")
    return mis_df

def evaluate_experiment(exp_name, result):
    model   = result["model"]
    exp_dir = result["experiment_dir"]

    y_true_ids, y_pred_ids, y_true_oh, y_prob = predict_dataset(model, test_ds)

    acc  = accuracy_score(y_true_ids, y_pred_ids)
    prec = precision_score(y_true_ids, y_pred_ids, average="macro", zero_division=0)
    rec  = recall_score(y_true_ids, y_pred_ids, average="macro", zero_division=0)
    f1   = f1_score(y_true_ids, y_pred_ids, average="macro", zero_division=0)
    try:
        auc = roc_auc_score(y_true_oh, y_prob, multi_class="ovr", average="macro")
    except Exception:
        auc = np.nan

    inf_info = measure_inference(model, test_ds)
    metrics  = {
        "experiment":       exp_name,
        "accuracy":         acc,
        "precision_macro":  prec,
        "recall_macro":     rec,
        "f1_macro":         f1,
        "auc_macro_ovr":    auc,
        **inf_info,
        **count_parameters(model),
        "training_time_seconds": result["training_info"]["training_time_seconds"],
        "best_epoch":            result["training_info"]["best_epoch"],
        "best_val_accuracy":     result["training_info"]["best_val_accuracy"],
    }
    pd.DataFrame([metrics]).to_csv(exp_dir / "metrics.csv", index=False)

    # Classification Report
    report = classification_report(
        y_true_ids, y_pred_ids, target_names=CLASS_NAMES,
        output_dict=True, zero_division=0,
    )
    pd.DataFrame(report).T.to_csv(exp_dir / "report" / "classification_report.csv")

    # Confusion Matrix
    cm = confusion_matrix(y_true_ids, y_pred_ids, labels=np.arange(NUM_CLASSES))
    plt.figure(figsize=(14, 11))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title(f"Confusion Matrix — {exp_name}")
    plt.xlabel("Predicted"); plt.ylabel("Actual")
    plt.xticks(rotation=90); plt.tight_layout()
    plt.savefig(exp_dir / "confusion_matrix" / "confusion_matrix.png", dpi=200)
    plt.show()

    # Simpan kesalahan model
    print(f"\nKesalahan model — {exp_name}:")
    save_misclassified(y_true_ids, y_pred_ids, y_prob, test_df, exp_dir)

    result.update({
        "metrics": metrics,
        "y_true_ids": y_true_ids, "y_pred_ids": y_pred_ids,
        "y_true_onehot": y_true_oh, "y_prob": y_prob,
    })
    return result

for exp_name in RESULTS:
    RESULTS[exp_name] = evaluate_experiment(exp_name, RESULTS[exp_name])

print("\nEvaluasi selesai.")

# %%
# Cell 12 — Export setiap eksperimen ke SavedModel, TFLite, dan TFJS

def export_saved_model(model, out_dir):
    out_dir = Path(out_dir)
    if out_dir.exists():
        shutil.rmtree(out_dir)
    try:
        model.export(str(out_dir))
    except Exception:
        tf.saved_model.save(model, str(out_dir))
    return out_dir

def export_tflite(model, out_path):
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = []
    tflite_bytes = converter.convert()
    with open(out_path, "wb") as f:
        f.write(tflite_bytes)
    return out_path

def export_tensorflowjs(saved_model_dir, tfjs_dir):
    tfjs_dir = Path(tfjs_dir)
    if tfjs_dir.exists():
        shutil.rmtree(tfjs_dir)
    ensure_dir(tfjs_dir)
    cmd = [sys.executable, "-m", "tensorflowjs.converters.converter",
           "--input_format=tf_saved_model", str(saved_model_dir), str(tfjs_dir)]
    res = subprocess.run(cmd, capture_output=True, text=True)
    if res.returncode != 0:
        res = subprocess.run(
            ["tensorflowjs_converter", "--input_format=tf_saved_model",
             str(saved_model_dir), str(tfjs_dir)],
            capture_output=True, text=True,
        )
    save_text(res.stdout + "\n" + res.stderr, tfjs_dir / "conversion_log.txt")
    if res.returncode == 0:
        print(f"TFJS OK → {tfjs_dir}")
    else:
        print(f"TFJS GAGAL: {res.stderr[:300]}")
    return tfjs_dir

def export_all_formats(exp_name, result):
    model   = result["model"]
    exp_dir = result["experiment_dir"]

    saved_model_dir = exp_dir / "saved_model" / "model"
    tflite_path     = exp_dir / "tflite" / "model.tflite"
    tfjs_dir        = exp_dir / "tensorflowjs"

    export_saved_model(model, saved_model_dir)
    export_tflite(model, tflite_path)
    export_tensorflowjs(saved_model_dir, tfjs_dir)

    export_info = {
        "saved_model_size_mb":     file_size_mb(saved_model_dir),
        "tflite_size_mb":          file_size_mb(tflite_path),
        "tensorflowjs_size_mb":    file_size_mb(tfjs_dir),
    }
    save_json(export_info, exp_dir / "report" / "export_info.json")
    result["export_info"] = export_info
    return result

for exp_name in RESULTS:
    print(f"\nExporting {exp_name}...")
    RESULTS[exp_name] = export_all_formats(exp_name, RESULTS[exp_name])

print("\nSemua export selesai.")
# Out:
# Exporting E1_MobileNetV3...
# INFO:tensorflow:Assets written to: /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/saved_model/model/assets
# INFO:tensorflow:Assets written to: /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/saved_model/model/assets
# Saved artifact at '/kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/saved_model/model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_6')
# Output Type:
#   TensorSpec(shape=(None, 24), dtype=tf.float32, name=None)
# Captures:
#   133632396593488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397153232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397153424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397152656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397152080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397151696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397153040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397154000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397154384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397153616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397154192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397152848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397228368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397228176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397227024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397228944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397228560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397227792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397227984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396701584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396701008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396689680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396689488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396701200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396690832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396690256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396690448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396690640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396689872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396692176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396692368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396692944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396693328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396693520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396692560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396693136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396694096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396693712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396693904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396695056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396694480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396695824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396695248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396694672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396692752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396695440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396694288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396694864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396697744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396697168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396697360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396697552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396695632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396698704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396698128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396699472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396698896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396699856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396698320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396699664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396700432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396699088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396698512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396700624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396697936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396700816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396700240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667098832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396699280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396700048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667100944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667100368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667101328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667100176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667101136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667101904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667100560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667101712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667102864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667102288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667102480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667102672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667100752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667103824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667103248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667103440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667103632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667101520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667102096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667105744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667105168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667105360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667105552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667103056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667106704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667106128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667106320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667106512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667107664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667107088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667107280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667107472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667108624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667108048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667108240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667108432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667105936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667106896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667110544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667110160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667110352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667107856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667111504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667110928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667111120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667110736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667112272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667111696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667111888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667112080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667111312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667108816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646124816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646126544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646126160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646126352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646124624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646127504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646126928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646128272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646127696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646128656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646127120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646128464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646129232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646127888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646126736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646127312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646129616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646129808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646128080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646131152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646128848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646131920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646131344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646132304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646129424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646132112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646132880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646131536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646132688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646133840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646133264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646133456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646133648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646131728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646132496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646135568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646135952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646133072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646135760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646136528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646135184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646136336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646137488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646136912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646137104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646137296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646135376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646138448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646137872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646136144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646138640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646138064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646136720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646140176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646138832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646137680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646140368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646140752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616699344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646140560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646138256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616699152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616699536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616700880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616700304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616701264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616699920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616700112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616701072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616701840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616700496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616698960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616701648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616699728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616702800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616702224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616702992: TensorSpec(shape=(), dtype=tf.resource, name=None)
# INFO:tensorflow:Assets written to: /tmp/tmpko2mu4hj/assets
# INFO:tensorflow:Assets written to: /tmp/tmpko2mu4hj/assets
# Saved artifact at '/tmp/tmpko2mu4hj'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_6')
# Output Type:
#   TensorSpec(shape=(None, 24), dtype=tf.float32, name=None)
# Captures:
#   133632396593488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397153232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397153424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397152656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397152080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397151696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397153040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397154000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397154384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397153616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397154192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397152848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397228368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397228176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397227024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397228944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397228560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397227792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397227984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396701584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632397229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396701008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396689680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396689488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396701200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396690832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396690256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396690448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396690640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396689872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396692176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396692368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396692944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396693328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396693520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396692560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396693136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396694096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396693712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396693904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396695056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396694480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396691216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396695824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396695248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396694672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396692752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396695440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396694288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396694864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396697744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396697168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396697360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396697552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396695632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396698704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396698128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396699472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396698896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396699856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396698320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396696976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396699664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396700432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396699088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396698512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396700624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396697936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396700816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396700240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667098832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396699280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133632396700048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667100944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667100368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667101328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667100176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667101136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667101904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667100560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667101712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667099792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667102864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667102288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667102480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667102672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667100752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667103824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667103248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667103440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667103632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667101520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667102096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667105744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667105168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667105360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667105552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667103056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667106704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667106128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667106320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667106512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667107664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667107088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667107280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667107472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667104976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667108624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667108048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667108240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667108432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667105936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667106896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667110544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667110160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667110352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667107856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667111504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667110928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667111120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667110736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667112272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667111696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667109776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667111888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667112080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667111312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630667108816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646124816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646126544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646126160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646126352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646124624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646127504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646126928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646128272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646127696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646128656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646127120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646125584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646128464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646129232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646127888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646126736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646127312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646129616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646129808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646128080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646131152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646128848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646131920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646131344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646132304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646129424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646132112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646132880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646131536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646132688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646130960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646133840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646133264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646133456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646133648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646131728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646132496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646135568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646135952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646133072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646135760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646136528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646135184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646136336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646134608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646137488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646136912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646137104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646137296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646135376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646138448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646137872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646136144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646138640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646138064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646136720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646140176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646138832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646137680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646140368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646140752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646139984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616699344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646140560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630646138256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616699152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616699536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616700880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616700304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616701264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616699920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616700112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616701072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616701840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616700496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616698960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616701648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616699728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616702800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616702224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133630616702992: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1785455697.083521      23 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1785455697.083568      23 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1785455697.272585      23 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# TFJS OK → /kaggle/working/Research_POS/EXPERIMENT/E1_MobileNetV3/tensorflowjs
#
# Exporting E2_MobileNetV3_CBAM...
# INFO:tensorflow:Assets written to: /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/saved_model/model/assets
# INFO:tensorflow:Assets written to: /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/saved_model/model/assets
# Saved artifact at '/kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/saved_model/model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_212')
# Output Type:
#   TensorSpec(shape=(None, 24), dtype=tf.float32, name=None)
# Captures:
#   133630616712400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037622224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037621840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037621648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037622800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037620496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037622416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037622608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037622032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037623760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037623184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037623376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037623568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037621456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037624720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037624144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037624336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037624528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037620880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037625680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037625104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037625296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037625488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037622992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037626640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037626064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037626256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037626448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037623952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037627600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037627024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037627216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037627408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037624912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037628560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037627984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037628176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037628368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037625872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037629520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037628944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037629136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037628752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037630288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037629712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037627792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037629904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037630096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037629328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037626832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682376464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682377616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682377424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682377040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682378192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682376656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682376272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682378960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682378384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682378768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682379728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682377232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682376848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682380304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682379152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682379920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682380112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682378576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682381264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682380688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682380880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682381072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682379536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682382224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682381648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682377808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682382992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682382416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682382800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682383760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682381456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682380496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682384336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682383184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682383952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682384144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682382608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682385296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682384720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682384912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682385104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682383568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682386256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682385680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682381840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682386448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682385872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682384528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682386640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682385488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682386064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682388944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682388368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682388560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682388752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682386832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682389904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682389328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682389520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682389712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682390864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682390288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682390480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682390672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682388176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682391824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682391248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682391440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682392016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682392400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682391056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682390096: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
#   133627037627792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037629904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037630096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037629328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133627037626832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682376464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682377616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682377424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682377040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682378192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682376656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682376272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682378960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682378384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682378768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682379728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682377232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682376848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682380304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682379152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682379920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682380112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682378576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682381264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682380688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682380880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682381072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682379536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682382224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682381648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682377808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682382992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682382416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682382800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682383760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682381456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682380496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682384336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682383184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682383952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682384144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682382608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682385296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682384720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682384912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682385104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682383568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682386256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682385680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682381840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682386448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682385872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682384528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682386640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682385488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682386064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682388944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682388368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682388560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682388752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682386832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682389904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682389328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682389520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682389712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682387600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682390864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682390288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682390480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682390672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682388176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682391824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682391248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682391440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682392016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682392400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682391056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682390096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682391632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680313040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682392208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626682389136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680312080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680312464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680312656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680312848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680314000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680313424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680313616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680313808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680311888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680314960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680314384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680314576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680314768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680312272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680315920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680315344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680315536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680315728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680313232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680316880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680316304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680316496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680316688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680314192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680317840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680317264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680317456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680317648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680315152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680318800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680318224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680318416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680318608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680316112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680319760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680319184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680319376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680319568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680317072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680320720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680320144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680318032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680321488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680320912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680321872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680320336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680318992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680321680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680322448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680321104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680319952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680322256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680320528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680323408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680322832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680323024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680323216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680321296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680324368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680323792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680322064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680325136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680324560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680325520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680323984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680322640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680325328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680326096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680324752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680323600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680325904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680324176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680327056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680326480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680326672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680327440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680324944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680328016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680326864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680327824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680327632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680326288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680325712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681311696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681312848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626680327248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681312272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681312656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681311312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681311504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681311888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681313808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681313232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681313424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681313616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681312464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681314768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681314192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681312080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681315536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681314960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681315920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681314384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681313040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681315728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681316496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681315152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681314000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681316304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681314576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681317456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681316880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681317072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681317264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681315344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681318416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681317840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681316112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681319184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681318608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681319568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681318032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681316688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681319376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681320144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681318800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681317648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681319952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681318224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681321104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681320336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681321296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681322256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681322064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681322640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681318992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133626681320912: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1785455732.395364      23 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1785455732.395402      23 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# TFJS OK → /kaggle/working/Research_POS/EXPERIMENT/E2_MobileNetV3_CBAM/tensorflowjs
#
# Semua export selesai.

# %%
# Cell 13 — Buat tabel perbandingan 2 model, pilih yang terbaik berdasarkan accuracy → f1 → inference

rows = []
for exp_name, result in RESULTS.items():
    row = result["metrics"].copy()
    ei  = result.get("export_info", {})
    row.update({
        "model_size_mb_keras":        file_size_mb(result["experiment_dir"] / "model" / "model.keras"),
        "model_size_mb_tflite":       ei.get("tflite_size_mb", np.nan),
        "model_size_mb_tensorflowjs": ei.get("tensorflowjs_size_mb", np.nan),
    })
    rows.append(row)

comparison_df = pd.DataFrame(rows)
comparison_df.to_csv(OUTPUT_ROOT / "COMPARISON" / "comparison_table.csv", index=False)

ranking_df = comparison_df.sort_values(
    by=["accuracy", "f1_macro", "inference_time_per_image_ms"],
    ascending=[False, False, True],
).reset_index(drop=True)
ranking_df["rank"] = np.arange(1, len(ranking_df) + 1)
ranking_df.to_csv(OUTPUT_ROOT / "COMPARISON" / "ranking.csv", index=False)

best_experiment_name = ranking_df.iloc[0]["experiment"]

print(f"\n{'='*60}")
print(f"Model terbaik: {best_experiment_name}")
print(f"{'='*60}")
display(ranking_df[["rank", "experiment", "accuracy", "f1_macro",
                     "auc_macro_ovr", "inference_time_per_image_ms",
                     "model_size_mb_tflite", "model_size_mb_tensorflowjs"]])
# Out:
# ============================================================
# Model terbaik: E2_MobileNetV3_CBAM
# ============================================================
#    rank           experiment  accuracy  f1_macro  auc_macro_ovr  \
# 0     1  E2_MobileNetV3_CBAM  0.995833  0.995833       0.999996
# 1     2       E1_MobileNetV3  0.995833  0.995832       0.999976
#
#    inference_time_per_image_ms  model_size_mb_tflite  \
# 0                     7.390683             12.310402
# 1                     7.188179             11.424202
#
#    model_size_mb_tensorflowjs
# 0                   13.372057
# 1                   11.594501

# %%
# Cell 14 — Salin model terbaik (TFJS + TFLite + Keras) ke folder FINAL_MODEL beserta class.json
#          + salin misclassified.csv + error_summary.csv + metrics + training_info

best_result  = RESULTS[best_experiment_name]
FINAL_DIR    = OUTPUT_ROOT / "FINAL_MODEL"

if FINAL_DIR.exists():
    shutil.rmtree(FINAL_DIR)
FINAL_DIR.mkdir(parents=True, exist_ok=True)

for folder in ["model", "saved_model", "tensorflowjs", "tflite", "weights", "report", "confusion_matrix"]:
    src = best_result["experiment_dir"] / folder
    if src.exists():
        shutil.copytree(src, FINAL_DIR / folder)

shutil.copy(best_result["experiment_dir"] / "metrics.csv", FINAL_DIR / "metrics.csv")

# Salin class.json ke dalam folder TFJS agar siap dipakai langsung di web
shutil.copy(OUTPUT_ROOT / "DATA_REPORT" / "class.json",
            FINAL_DIR / "tensorflowjs" / "class.json")

# ── Ringkasan lengkap untuk halaman admin ──────────────────────
# Mengumpulkan: metrik, training info, kesalahan model, error summary → 1 JSON
best_metrics = best_result["metrics"]
best_train   = best_result["training_info"]

# Baca misclassified + error_summary
misclassified_path = best_result["experiment_dir"] / "report" / "misclassified.csv"
error_summary_path = best_result["experiment_dir"] / "confusion_matrix" / "error_summary.csv"

misclassified_list = []
if misclassified_path.exists():
    misclassified_list = pd.read_csv(misclassified_path).to_dict("records")

error_summary_list = []
if error_summary_path.exists():
    error_summary_list = pd.read_csv(error_summary_path).to_dict("records")

# Baca history training
history_path = best_result["experiment_dir"] / "history" / "history.csv"
history_list = []
if history_path.exists():
    history_list = pd.read_csv(history_path).to_dict("records")

# Baca classification report
cls_report_path = best_result["experiment_dir"] / "report" / "classification_report.csv"
cls_report_dict = {}
if cls_report_path.exists():
    cls_report_df = pd.read_csv(cls_report_path, index_col=0)
    cls_report_dict = cls_report_df.to_dict("index")

training_summary = {
    "best_experiment":    best_experiment_name,
    "selection_rule":     ["accuracy desc", "f1_macro desc", "inference_time_per_image_ms asc"],
    "accuracy":           float(best_metrics["accuracy"]),
    "f1_macro":           float(best_metrics["f1_macro"]),
    "precision_macro":    float(best_metrics["precision_macro"]),
    "recall_macro":       float(best_metrics["recall_macro"]),
    "auc_macro_ovr":      float(best_metrics["auc_macro_ovr"]) if not np.isnan(best_metrics["auc_macro_ovr"]) else None,
    "inference_ms":       float(best_metrics["inference_time_per_image_ms"]),
    "fps":                float(best_metrics["fps"]),
    "parameters":         int(best_metrics["parameters"]),
    "best_epoch":         int(best_metrics["best_epoch"]),
    "best_val_accuracy":  float(best_metrics["best_val_accuracy"]),
    "training_time_s":    float(best_metrics["training_time_seconds"]),
    "num_classes":        NUM_CLASSES,
    "num_test_images":    len(test_df),
    "num_misclassified":  len(misclassified_list),
    "training_history":   history_list,
    "classification_report": cls_report_dict,
    "error_summary":      error_summary_list,
    "misclassified_samples": misclassified_list[:50],  # top 50 saja
    "generated_at":       now_string(),
}

save_json(training_summary, FINAL_DIR / "training_summary.json")
save_json(training_summary, FINAL_DIR / "tensorflowjs" / "training_summary.json")

save_json({
    "best_experiment":  best_experiment_name,
    "selection_rule":   ["accuracy desc", "f1_macro desc", "inference_time_per_image_ms asc"],
    "accuracy":         best_result["metrics"]["accuracy"],
    "f1_macro":         best_result["metrics"]["f1_macro"],
}, FINAL_DIR / "best_model_info.json")

print(f"FINAL_MODEL siap di: {FINAL_DIR}")
print(f"Isi FINAL_MODEL/tensorflowjs:")
for f in sorted((FINAL_DIR / "tensorflowjs").iterdir()):
    print(f"  {f.name}  ({file_size_mb(f):.2f} MB)")
print(f"\ntraining_summary.json siap untuk halaman admin.")
print(f"  Misclassified: {len(misclassified_list)} gambar")
print(f"  Error summary: {len(error_summary_list)} class dengan error")

# %%
# Cell 16 — Ringkasan akurasi evaluasi kedua model dalam DataFrame

metrics_cols = [
    "experiment",
    "accuracy",
    "precision_macro",
    "recall_macro",
    "f1_macro",
    "auc_macro_ovr",
    "top5_accuracy",
    "inference_time_per_image_ms",
    "fps",
    "parameters",
    "best_epoch",
    "best_val_accuracy",
    "training_time_seconds",
]

eval_rows = []
for exp_name, result in RESULTS.items():
    m = result["metrics"]
    eval_rows.append({col: m.get(col, np.nan) for col in metrics_cols})

eval_df = pd.DataFrame(eval_rows)

# Format angka biar rapi
format_map = {
    "accuracy":                    "{:.4f}",
    "precision_macro":             "{:.4f}",
    "recall_macro":                "{:.4f}",
    "f1_macro":                    "{:.4f}",
    "auc_macro_ovr":               "{:.4f}",
    "top5_accuracy":               "{:.4f}",
    "inference_time_per_image_ms": "{:.4f}",
    "fps":                         "{:.2f}",
    "best_val_accuracy":           "{:.4f}",
    "training_time_seconds":       "{:.1f}",
}

eval_display = eval_df.copy()
for col, fmt in format_map.items():
    if col in eval_display.columns:
        eval_display[col] = eval_display[col].apply(lambda x: fmt.format(x) if pd.notna(x) else "-")

display(eval_display)

# Highlight model terbaik
best = eval_df.loc[eval_df["accuracy"].idxmax(), "experiment"]
best_acc = eval_df["accuracy"].max()
print(f"\nModel terbaik : {best}")
print(f"Accuracy      : {best_acc:.4f} ({best_acc*100:.2f}%)")
# Out:
#             experiment accuracy precision_macro recall_macro f1_macro  \
# 0       E1_MobileNetV3   0.9958          0.9960       0.9958   0.9958
# 1  E2_MobileNetV3_CBAM   0.9958          0.9959       0.9958   0.9958
#
#   auc_macro_ovr top5_accuracy inference_time_per_image_ms     fps  parameters  \
# 0        1.0000             -                      7.1882  139.12     3019418
# 1        1.0000             -                      7.3907  135.31     3250996
#
#    best_epoch best_val_accuracy training_time_seconds
# 0          50            0.9958                1086.1
# 1          50            0.9931                1055.9
# Model terbaik : E1_MobileNetV3
# Accuracy      : 0.9958 (99.58%)

# %%
# Cell 17 — ZIP isi TFJS best model (model.json + *.bin + class.json), nama ZIP = nama model

import os
from IPython.display import FileLink, display as ipy_display

TFJS_DIR = FINAL_DIR / "tensorflowjs"
ZIP_PATH = str(OUTPUT_ROOT / f"{best_experiment_name}.zip")

if os.path.exists(ZIP_PATH):
    os.remove(ZIP_PATH)

# Hanya ambil file relevan saja, exclude conversion_log.txt
include_files = (
    list(TFJS_DIR.glob("model.json")) +
    list(TFJS_DIR.glob("*.bin")) +
    [TFJS_DIR / "class.json"]
)

# Pastikan class.json ada
if not (TFJS_DIR / "class.json").exists():
    shutil.copy(OUTPUT_ROOT / "DATA_REPORT" / "class.json", TFJS_DIR / "class.json")

file_list = " ".join(f'"{f.name}"' for f in include_files if f.exists())
os.system(f'cd "{TFJS_DIR}" && zip -q "{ZIP_PATH}" {file_list}')

size_mb = os.path.getsize(ZIP_PATH) / (1024 * 1024)
print(f"ZIP     : {best_experiment_name}.zip")
print(f"Ukuran  : {size_mb:.2f} MB")
print(f"Isi ZIP :")
for f in include_files:
    if f.exists():
        print(f"  ✓ {f.name}  ({file_size_mb(f):.3f} MB)")

ipy_display(FileLink(ZIP_PATH))
# Out:
# ZIP     : E2_MobileNetV3_CBAM.zip
# Ukuran  : 12.26 MB
# Isi ZIP :
#   ✓ model.json  (0.204 MB)
#   ✓ group1-shard3of4.bin  (4.000 MB)
#   ✓ group1-shard2of4.bin  (4.000 MB)
#   ✓ group1-shard1of4.bin  (4.000 MB)
#   ✓ group1-shard4of4.bin  (1.165 MB)
#   ✓ class.json  (0.001 MB)
# /kaggle/working/Research_POS/E2_MobileNetV3_CBAM.zip
